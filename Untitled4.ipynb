# %% [markdown]
# <a href="https://colab.research.google.com/github/ebrahim43/CNN-Model-On-PASCAL_VOC-Dataset/blob/main/Untitled4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install tensorflow
# !pip install lxml
# !pip install tqdm

# %%
# Create directories for the dataset
# !mkdir -p /content/dataset

# Download the PASCAL VOC dataset
# !wget http://host.robots.ox.ac.uk/pascal/VOC/voc2012/VOCtrainval_11-May-2012.tar -O /content/dataset/VOCtrainval_11-May-2012.tar

# Extract the dataset
# !tar -xvf /content/dataset/VOCtrainval_11-May-2012.tar -C /content/dataset
# Out:
# Streaming output truncated to the last 5000 lines.
# VOCdevkit/VOC2012/SegmentationClass/2008_001874.png
# VOCdevkit/VOC2012/SegmentationClass/2008_001876.png
# VOCdevkit/VOC2012/SegmentationClass/2008_001882.png
# VOCdevkit/VOC2012/SegmentationClass/2008_001885.png
# VOCdevkit/VOC2012/SegmentationClass/2008_001895.png
# VOCdevkit/VOC2012/SegmentationClass/2008_001896.png
# VOCdevkit/VOC2012/SegmentationClass/2008_001926.png
# VOCdevkit/VOC2012/SegmentationClass/2008_001966.png
# VOCdevkit/VOC2012/SegmentationClass/2008_001971.png
# VOCdevkit/VOC2012/SegmentationClass/2008_001992.png
# VOCdevkit/VOC2012/SegmentationClass/2008_001997.png
# VOCdevkit/VOC2012/SegmentationClass/2008_002032.png
# VOCdevkit/VOC2012/SegmentationClass/2008_002043.png
# VOCdevkit/VOC2012/SegmentationClass/2008_002064.png
# VOCdevkit/VOC2012/SegmentationClass/2008_002066.png
# VOCdevkit/VOC2012/SegmentationClass/2008_002067.png
# VOCdevkit/VOC2012/SegmentationClass/2008_002073.png
# ...

# %%
import os
import xml.etree.ElementTree as ET
import numpy as np
from tqdm import tqdm
from PIL import Image
import tensorflow as tf
from tensorflow.keras import layers, models
import matplotlib.pyplot as plt

# Define the paths to the dataset
dataDir = '/content/dataset/VOCdevkit/VOC2012'
imgDir = os.path.join(dataDir, 'JPEGImages')
annDir = os.path.join(dataDir, 'Annotations')

# PASCAL VOC classes
class_names = ['aeroplane', 'bicycle', 'bird', 'boat', 'bottle',
               'bus', 'car', 'cat', 'chair', 'cow', 'diningtable',
               'dog', 'horse', 'motorbike', 'person', 'pottedplant',
               'sheep', 'sofa', 'train', 'tvmonitor']

class_to_index = {cls: idx for idx, cls in enumerate(class_names)}

# Function to load images
def load_image(img_path):
    img = Image.open(img_path).convert('RGB')
    img = img.resize((128, 128))  # Resize to 128x128 for the model
    return np.array(img) / 255.0

# Function to load annotations
def load_annotations(ann_path):
    tree = ET.parse(ann_path)
    root = tree.getroot()
    labels = np.zeros(len(class_names))
    for obj in root.findall('object'):
        cls = obj.find('name').text
        if cls in class_to_index:
            labels[class_to_index[cls]] = 1
    return labels

# Load images and labels
X = []
y = []

img_files = os.listdir(imgDir)
ann_files = os.listdir(annDir)

for img_file in tqdm(img_files[:5000]):  # Limiting to 5000 images for the example
    img_path = os.path.join(imgDir, img_file)
    ann_path = os.path.join(annDir, img_file.replace('.jpg', '.xml'))
    if os.path.exists(ann_path):
        img_data = load_image(img_path)
        labels = load_annotations(ann_path)
        X.append(img_data)
        y.append(labels)

X = np.array(X)
y = np.array(y)

print(f'Loaded {len(X)} images')
# Out:
# 100%|██████████| 5000/5000 [00:25<00:00, 192.42it/s]
# Loaded 5000 images

# %%
# Define the CNN model
model = models.Sequential()
model.add(layers.Conv2D(32, (3, 3), activation='relu', input_shape=(128, 128, 3)))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Conv2D(64, (3, 3), activation='relu'))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Conv2D(64, (3, 3), activation='relu'))

model.add(layers.Flatten())
model.add(layers.Dense(128, activation='relu'))
model.add(layers.Dense(len(class_names), activation='sigmoid'))

# Display the model's architecture
model.summary()

# Compile the model
model.compile(optimizer='adam',
              loss='binary_crossentropy',
              metrics=['accuracy'])

# Train the model
history = model.fit(X, y, epochs=10, validation_split=0.2)

# Plot the training history
plt.plot(history.history['accuracy'], label='accuracy')
plt.plot(history.history['val_accuracy'], label='val_accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.ylim([0, 1])
plt.legend(loc='lower right')
plt.show()

# Evaluate the model
test_loss, test_acc = model.evaluate(X, y, verbose=2)
print(f"Test Accuracy: {test_acc}")
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                      │ (None, 126, 126, 32)        │             896 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d (MaxPooling2D)         │ (None, 63, 63, 32)          │               0 │
# ...

# %%
import os

dataset_path = 'C:\\my_projects\\my_data\\dataset_with_multilabel_classification' # Use the path from explorer
#dataset_path = 'C:\\test_dir\\dataset_with_multilabel_classification' # Use the simplified path if that is the case

try:
    contents = os.listdir(dataset_path)
    print(f"Directory found at: {dataset_path}")
    print(f"Contents: {contents}")
except FileNotFoundError as e:
    print(f"Error: Directory not found at {dataset_path}. {e}")
# Out:
# Error: Directory not found at C:\my_projects\my_data\dataset_with_multilabel_classification. [Errno 2] No such file or directory: 'C:\\my_projects\\my_data\\dataset_with_multilabel_classification'

# %%
# !mkdir /content/test_images

# %%
# !cp /content/dataset/VOCdevkit/VOC2012/JPEGImages/2007_000027.jpg  /content/test_images/
# !cp /content/dataset/VOCdevkit/VOC2012/JPEGImages/2007_000032.jpg  /content/test_images/
# !cp /content/dataset/VOCdevkit/VOC2012/JPEGImages/2007_000033.jpg  /content/test_images/
# !cp /content/dataset/VOCdevkit/VOC2012/JPEGImages/2007_000039.jpg  /content/test_images/
# !cp /content/dataset/VOCdevkit/VOC2012/JPEGImages/2007_000042.jpg  /content/test_images/
# !cp /content/dataset/VOCdevkit/VOC2012/JPEGImages/2007_000061.jpg  /content/test_images/
# !cp /content/dataset/VOCdevkit/VOC2012/JPEGImages/2007_000063.jpg  /content/test_images/
# !cp /content/dataset/VOCdevkit/VOC2012/JPEGImages/2007_000068.jpg  /content/test_images/
# !cp /content/dataset/VOCdevkit/VOC2012/JPEGImages/2007_000121.jpg  /content/test_images/
# !cp /content/dataset/VOCdevkit/VOC2012/JPEGImages/2007_000128.jpg  /content/test_images/
# Out:
# cp: cannot stat '/content/dataset/VOCdevkit/VOC2012/JPEGImages/2007_000128.jpg': No such file or directory

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.preprocessing import image
import os
import random

# --- Test Images Code (Modified for Colab)

# --- 2. Define a function to load test images
def load_test_images(image_paths):
    test_images = []
    for img_path in image_paths:
        img = image.load_img(img_path, target_size=(128, 128))
        img_array = image.img_to_array(img) / 255.0
        test_images.append(img_array)
    return np.array(test_images)

# --- 3. Get a list of all image files in the test directory
test_dir = "/content/test_images" # Your test image directory

all_test_images = []

try:
    for filename in os.listdir(test_dir):
        if filename.endswith('.jpg') or filename.endswith('.png'):
            all_test_images.append(os.path.join(test_dir, filename))
except FileNotFoundError as e:
    print(f"Error accessing test image directory: {e}. Make sure directory: {test_dir} exists")
    all_test_images = [] # Set this to empty so the code continues

# --- 4. Randomly select 10 test images
num_test_images = 10
if len(all_test_images) >= num_test_images:
    test_image_paths = random.sample(all_test_images, num_test_images)
else:
    print(f"Warning: Only {len(all_test_images)} images found in test directory. Using all available images.")
    test_image_paths = all_test_images

if len(test_image_paths) > 0:  # Add a check to see if there were any images found
    # --- 5. Load and preprocess the test images
    test_images = load_test_images(test_image_paths)

    # --- 6. Make predictions
    predictions = model.predict(test_images)


    # --- 7. Convert predictions to descriptions
    def get_image_descriptions(predictions, class_names):
        descriptions = []
        for pred in predictions:
            predicted_classes = class_names[pred > 0.5] # Applying the threshold of 0.5 for multilabel output
            descriptions.append(", ".join(predicted_classes)) # Join classes with commas if multiple exist
        return descriptions

    image_descriptions = get_image_descriptions(predictions, class_names)

    # --- 8. Output results
    for i, (img_path, desc) in enumerate(zip(test_image_paths, image_descriptions)):
        print(f"Image {i+1}: {os.path.basename(img_path)} Predicted labels: {desc}")
else:
    print("No test images could be found. Please check the path and that the files are either .jpg or .png")
# Out:
# ...
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 755ms/step
# Image 1: 2007_000121.jpg Predicted labels: person, sofa
# Image 2: 2007_000042.jpg Predicted labels: person
# Image 3: 2007_000027.jpg Predicted labels: person
# Image 4: 2007_000068.jpg Predicted labels: cat
# Image 5: 2007_000039.jpg Predicted labels:
# Image 6: 2007_000061.jpg Predicted labels:
# Image 7: 2007_000032.jpg Predicted labels:
# Image 8: 2007_000063.jpg Predicted labels: person
# Image 9: 2007_000033.jpg Predicted labels: person

# %%
num_test_images = 50

# %%
import os
import random
import shutil

# Define paths
image_dir = '/content/dataset/VOCdevkit/VOC2012/JPEGImages'
test_dir = '/content/test_images'

# 1. Create the test_images directory if it doesn't exist
os.makedirs(test_dir, exist_ok=True)

# 2. List all JPG images in the source directory
all_images = [f for f in os.listdir(image_dir) if f.endswith('.jpg')]


# 3. Check if there are at least 50 images in the directory
num_images_to_copy = 50
if len(all_images) >= num_images_to_copy:
  # 4. Select 50 random images
  selected_images = random.sample(all_images, num_images_to_copy)
else:
  print(f"Warning: Only {len(all_images)} images found in the source directory. Using all available images")
  selected_images = all_images
  num_images_to_copy = len(all_images)

# 5. Copy the selected images
print(f"Copying {num_images_to_copy} images to {test_dir}...")
for img in selected_images:
    source_path = os.path.join(image_dir, img)
    dest_path = os.path.join(test_dir, img)
    shutil.copy(source_path, dest_path)

print("Done copying images.")
# Out:
# Copying 50 images to /content/test_images...
# Done copying images.

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.preprocessing import image
import os
import random

# --- Test Images Code (Modified for Colab)

# --- 2. Define a function to load test images
def load_test_images(image_paths):
    test_images = []
    for img_path in image_paths:
        img = image.load_img(img_path, target_size=(128, 128))
        img_array = image.img_to_array(img) / 255.0
        test_images.append(img_array)
    return np.array(test_images)

# --- 3. Get a list of all image files in the test directory
test_dir = "/content/test_images" # Your test image directory

all_test_images = []

try:
    for filename in os.listdir(test_dir):
        if filename.endswith('.jpg') or filename.endswith('.png'):
            all_test_images.append(os.path.join(test_dir, filename))
except FileNotFoundError as e:
    print(f"Error accessing test image directory: {e}. Make sure directory: {test_dir} exists")
    all_test_images = [] # Set this to empty so the code continues

if not all_test_images:  # Check if all_test_images is empty after the try block
  print("No test images were found. Please check the path and that the files are either .jpg or .png.")
else:
    # --- 4. Randomly select 50 test images
    num_test_images = 50
    if len(all_test_images) >= num_test_images:
        test_image_paths = random.sample(all_test_images, num_test_images)
    else:
        print(f"Warning: Only {len(all_test_images)} images found in test directory. Using all available images.")
        test_image_paths = all_test_images


    # --- 5. Load and preprocess the test images
    test_images = load_test_images(test_image_paths)

    # --- 6. Make predictions
    predictions = model.predict(test_images)


    # --- 7. Convert predictions to descriptions
    def get_image_descriptions(predictions, class_names):
        descriptions = []
        for pred in predictions:
            # Get the class index with the highest probability
            predicted_class_index = np.argmax(pred)
            if pred[predicted_class_index] > 0.5:
              predicted_class = class_names[predicted_class_index]
              descriptions.append(predicted_class)
            else:
              descriptions.append("No labels") # use this when the score is below the threshold
        return descriptions

    image_descriptions = get_image_descriptions(predictions, class_names)

    # --- 8. Output results
    for i, (img_path, desc) in enumerate(zip(test_image_paths, image_descriptions)):
        print(f"Image {i+1}: {os.path.basename(img_path)} Predicted labels: {desc}")
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 616ms/step
# Image 1: 2007_000033.jpg Predicted labels: person
# Image 2: 2010_004585.jpg Predicted labels: No labels
# Image 3: 2007_000027.jpg Predicted labels: person
# Image 4: 2007_007772.jpg Predicted labels: cat
# Image 5: 2008_002541.jpg Predicted labels: person
# Image 6: 2011_002218.jpg Predicted labels: tvmonitor
# Image 7: 2008_007389.jpg Predicted labels: car
# Image 8: 2007_000039.jpg Predicted labels: No labels
# Image 9: 2012_002537.jpg Predicted labels: sofa
# Image 10: 2008_007061.jpg Predicted labels: person
# Image 11: 2009_000931.jpg Predicted labels: No labels
# Image 12: 2009_000867.jpg Predicted labels: pottedplant
# Image 13: 2010_000785.jpg Predicted labels: dog
# Image 14: 2008_004387.jpg Predicted labels: car
# Image 15: 2011_006034.jpg Predicted labels: person
# Image 16: 2011_002661.jpg Predicted labels: boat
# Image 17: 2007_000042.jpg Predicted labels: person
# Image 18: 2012_002191.jpg Predicted labels: dog
# ...
